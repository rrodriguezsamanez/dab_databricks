# %% [markdown]
# # Transactions Summary
#
# Ventas por producto y método de pago. Segunda tarea del job
# `bakehouse_data_refresh`; depende de `customer_360`.

# %%
# Para probar a mano: descomentar, ejecutar y volver a comentar antes del commit.
# dbutils.widgets.removeAll()
# dbutils.widgets.text("catalog", "bakehouse_analytics_dev")
# dbutils.widgets.text("schema", "rnd")

# %%
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")

spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}")
spark.sql(f"USE SCHEMA {schema}")

# %%
spark.sql(f"""
CREATE OR REPLACE TABLE {catalog}.{schema}.transactions_summary AS
SELECT product,
       paymentMethod,
       SUM(quantity)   AS total_quantity,
       SUM(totalPrice) AS total_price
FROM samples.bakehouse.sales_transactions
GROUP BY product, paymentMethod
""")
